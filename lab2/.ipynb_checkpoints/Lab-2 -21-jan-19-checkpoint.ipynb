# %% [markdown]
# # Excercise-1 Plotting

# %% [markdown]
# # Scatter Plot

# %%
import seaborn as sns
import pandas as pd

import matplotlib.pyplot as plt
sns.set(style="whitegrid")

df  = pd.read_csv('./vehicles.csv')

sns_plot = sns.lmplot(df.columns[0], df.columns[1], data=df, fit_reg=False)

# %%
sns_plot.axes[0,0].set_ylim(0,)
sns_plot.axes[0,0].set_xlim(0,)
# Out:
# (0, 40.526886152619156)

# %%
sns_plot.savefig("scaterplot.png",bbox_inches='tight')
sns_plot.savefig("scaterplot.pdf",bbox_inches='tight')

# %% [markdown]
# # Histogram

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
sns_plot  = pd.read_csv('./vehicles.csv')
#df = sb.load_dataset('iris')
sb.distplot(sns_plot['Current fleet'],bins=10 ,kde = False)

plt.show()

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
sns_plot  = pd.read_csv('./vehicles.csv')
#print(sns_plot)
#df = sb.load_dataset('iris')
sb.distplot(sns_plot['New Fleet'],bins=30 ,kde = False)

plt.show()
# Out:
# /Users/nimitkhanna/anaconda3/lib/python3.6/site-packages/matplotlib/figure.py:445: UserWarning: Matplotlib is currently using agg, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
import matplotlib
matplotlib.use('Agg')
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


def mad(arr):
    """ Median Absolute Deviation: a "Robust" version of standard deviation.
        Indices variabililty of the sample.
        https://en.wikipedia.org/wiki/Median_absolute_deviation 
        http://stackoverflow.com/questions/8930370/where-can-i-find-mad-mean-absolute-deviation-in-scipy
    """
    arr = np.ma.array(arr).compressed() # should be faster to not use masked arrays.
    med = np.median(arr)
    return np.median(np.abs(arr - med))


if __name__ == "__main__":
	df = pd.read_csv('./vehicles.csv')
	print((df.columns))
	sns_plot = sns.lmplot(df.columns[0], df.columns[1], data=df, fit_reg=False)

	sns_plot.axes[0,0].set_ylim(0,)
	sns_plot.axes[0,0].set_xlim(0,)

	sns_plot.savefig("scaterplot.png",bbox_inches='tight')
	sns_plot.savefig("scaterplot.pdf",bbox_inches='tight')

	data = df.values.T[1]
	
	#print((("Mean: %f")%(np.mean(data))))
	#print((("Median: %f")%(np.median(data))))
	#print((("Var: %f")%(np.var(data))))
	#print((("std: %f")%(np.std(data))))
	#print((("MAD: %f")%(mad(data))))

	plt.clf()
	sns_plot2 = sns.distplot(data, bins=30, kde=False, rug=True).get_figure()

	axes = plt.gca()
	axes.set_xlabel('Current Fleet') 
	axes.set_ylabel('New Fleet')

	sns_plot2.savefig("histogram.png",bbox_inches='tight')
	sns_plot2.savefig("histogram.pdf",bbox_inches='tight')
# Out:
# Index(['Current fleet', 'New Fleet'], dtype='object')

# %%
import matplotlib
matplotlib.use('Agg')
import pandas as pd
import seaborn as sns
import numpy as np


def boostrap(data, sample_size, iterations):
	# <---INSERT YOUR CODE HERE--->


	data = df.values.T[1]

	sample_size = 1.0
	iterations = 1000
	#confidence = 0.95

	data_mean = np.mean
	lower, upper = boostrap(data,iterations=iterations,sample_size=sample_size)
	return data_mean, lower, upper


if __name__ == "__main__":
	df = pd.read_csv('./salaries.csv')

	data = df.values.T[1]
	boots = []
	for i in range(100, 100000, 1000):
		boot = boostrap(data, data.shape[0], i)
		boots.append([i, boot[0], "mean"])
		boots.append([i, boot[1], "lower"])
		boots.append([i, boot[2], "upper"])

	df_boot = pd.DataFrame(boots, columns=['Boostrap Iterations', 'Mean', "Value"])
	sns_plot = sns.lmplot(df_boot.columns[0], df_boot.columns[1], data=df_boot, fit_reg=False, hue="Value")

	sns_plot.axes[0, 0].set_ylim(0,)
	sns_plot.axes[0, 0].set_xlim(0, 100000)

	sns_plot.savefig("bootstrap_confidence.png", bbox_inches='tight')
	sns_plot.savefig("bootstrap_confidence.pdf", bbox_inches='tight')


	#print ("Mean: %f")%(np.mean(data))
	#print ("Var: %f")%(np.var(data))
# Out:
#   File "<ipython-input-50-0e760d445ca8>", line 14
#     sample_size = 1.0
#     ^
# IndentationError: unexpected indent
